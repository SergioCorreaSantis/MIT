# %% [markdown]
# ![title](Pictures/MIT.png)
#
#  #  <font color='#B30838'> Vehicle Routing Problem - VRP | Cplex | V[3]. </font>
#
# <div class="alert alert-info">  </h4> **Rich Vehicle Routing problem with Capacity contratins, Time Windows and Heterogeneous Fleet.**
# </h4> </div>
#
#
# ##  <font color= #B30838> Descripción del Problema </font>
#
# **Problema de Samsonite: VRP, con capacidad, ventanas de tiempo, tiempo de viaje y tiempo de servicio.** Esta versión es solo de prueba del modelo, luego se modificará la función objetivo para minimizar el número de camiones a utilizar y flota heterogenea.
#
# - $C:$ Set of Clients $C=(1,2,3....n)$
# - $Nodes (N) = \{0\} \cup C$ Set of Node where "0" represet the DC.
# - $K:$ Set of Vehicule $K=(1,2,3,....K)$
# - $Arch= \{(i,j) \in N^2 : i \neq j\}$
# - $Conextions= \{(i,j,k) \in N^3 : i \neq j \; ; \; k  \in K \}$
# - $SubConextion= \{(i,k) \in N^2 : i \in C \; ; \; k  \in K \}$
#
#
# - $d_{ijk}:$ Distance from node i to j with truck k $(i,j,k)\in Conextions$
# - $q_i$ Customer's demand $i$ with $i\in Clientes$
# - $s_{i}:$ service time in each client $i$ with $i \in Clientes$
# - $t_{ij}:$ traveling Time from $i$ to $j$ with the vehicule $k$ $i,j \in Nodos$ & $k \in K$
# - $k_{i}$ capacity of the vehicle $k$ with $i \in K$
#
# ##  <font color= #B30838> Formulación Matemática del Problema </font>
#
#
# ####  <font color= #B30838> Variables de Decisión </font>
#
# - $x_{ijk}$ equals to 1 if we go from arch $i$ to arch $j$ with truck $k$ with $i,j \in C$ and $k \in K$ other way $0$.
# - $t_{ik}$ accumulated time in the node $i$ with the truck $k$ with $ i \in Clientes$ & $k \in K$
#
# ####  <font color= #B30838> Modelo </font>
#
# $Min \; Z= \; \displaystyle\sum_{k\in K}^{} \displaystyle\sum_{(i,j)\in A}^{}x_{ijk}c_{i}$
#
# subjet to:
#
#
# $\displaystyle\sum_{j \in N}x_{0jk} \leq 1$  $\;\; \forall \;k \in K$
#
# $\displaystyle\sum_{i \in N}x_{i0k} \leq 1$  $\;\; \forall \;k \in K$
#
# $\displaystyle\sum_{i \in N}x_{ijk}-\displaystyle\sum_{i \in N}x_{jik} =0$ $\;\; \forall \; j \in C \; \forall \; k \in K$
#
#
# $\displaystyle\sum_{j \in N}\displaystyle\sum_{k \in k}x_{ijk}=1$  $\;\; \forall i \in C$
#
# $\displaystyle\sum_{i \in N}q_{i}\displaystyle\sum_{j \in \delta^{+}(i)}x_{ijk}=k_{k}$ $\;\; \forall \;k \in K$
#
# if $x_{ijk}=1 \Longrightarrow$ $t_{ik}+s{i}+t_{ij}=t_{jk}$ $\;\; \forall \;k \in K,\;(i,j) \in A $
#
# $a_i \leq t_{ik} \leq b$   $\;\; \forall \;k \in K, \; \; i \in C$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import googlemaps
import folium
from folium import features
from geopy import distance
from datetime import datetime
from docplex.mp.model import Model

# %%
excel=pd.ExcelFile('/Users/sergiocorreasantis/Desktop/MIT ZLC Program/VRP Castom Project/CVRPTW | HF/Pedidos.xlsx')
df =pd.read_excel(excel,'Datos')

# %%
excel=pd.ExcelFile('/Users/sergiocorreasantis/Desktop/MIT ZLC Program/VRP Castom Project/Data Test/TimeWindows.xlsx')
TimeWindows =pd.read_excel(excel,'Sheet1')

# %%
# completar el DF con la información de TimeWindows

df['Inicio']=''
df['Final']=''
df['Duracion']=''
for i in range(len(df)):
    for j in range(len(TimeWindows)):
        if df.iloc[i][0]==TimeWindows.iloc[j][0]:
            df.at[i,'Inicio']=TimeWindows.iloc[j][1]
            df.at[i,'Final']=TimeWindows.iloc[j][2]
            df.at[i,'Duracion']=TimeWindows.iloc[j][3]*60

# %%
data=[]
data.insert(0,{'Cliente': 'Camino lo Boza 120-B, Pudahuel','Demanda': 0,
               'Inicio': 0,'Final': 0,'Duracion': 0})
df=pd.concat([pd.DataFrame(data), df], ignore_index=True)
df.head()
# Out:
#                           Cliente    Demanda Duracion     Final    Inicio
# 0  Camino lo Boza 120-B, Pudahuel   0.000000        0         0         0
# 1   Loc B2 SAX Outlet Irarrazabal   2.800000       60  11:30:00  09:30:00
# 2   Loc B2 SAX Outlet Irarrazabal  15.666667       60  11:30:00  09:30:00
# 3   Loc B2 SAX Outlet Irarrazabal  41.000000       60  11:30:00  09:30:00
# 4      Loc 57 SAM Alto Las Condes   3.800000       90  11:00:00  09:00:00

# %%
df['lat']=''
df['lon']=''

# %%
gmaps_key=googlemaps.Client(key="AIzaSyCCYm4751apdVLwDkG_QhLagjP7xNzt8Ac")
df['lat']=''
df['lon']=''

for n in range(len(df)):
    geocode_resultado=gmaps_key.geocode(df.iloc[n][0]+",Santiago"+",Chile")
    try:
        lat=geocode_resultado[0]["geometry"]["location"]["lat"]
        lon=geocode_resultado[0]["geometry"]["location"]["lng"]
        df.at[n,'lat']=lat
        df.at[n,'lon']=lon
    except:
        lat=None
        lon=None
df.head()
# Out:
#                           Cliente    Demanda Duracion     Final    Inicio  \
# 0  Camino lo Boza 120-B, Pudahuel   0.000000        0         0         0
# 1   Loc B2 SAX Outlet Irarrazabal   2.800000       60  11:30:00  09:30:00
# 2   Loc B2 SAX Outlet Irarrazabal  15.666667       60  11:30:00  09:30:00
# 3   Loc B2 SAX Outlet Irarrazabal  41.000000       60  11:30:00  09:30:00
# 4      Loc 57 SAM Alto Las Condes   3.800000       90  11:00:00  09:00:00
#
#        lat      lon
# 0  -33.382  -70.768
# 1 -33.4541 -70.6043
# 2 -33.4541 -70.6043
# 3 -33.4541 -70.6043
# 4 -33.3908  -70.546

# %%
excel=pd.ExcelFile('/Users/sergiocorreasantis/Desktop/MIT ZLC Program/VRP Castom Project/CVRPTW | HF/FLOTA CAMIONES.xlsx')
fleet =pd.read_excel(excel,'Hoja1')
fleet.head()
# Out:
#   PATENTE   VOLUMEN            CHOFER      CELULAR           RUT  \
# 0   HKRT76        25     CARLOS LOPEZ  966465979.0  13,669,063-9
# 1   JDFV82        40    ESTEBAN DURAN  966337566.0  15,372,778-3
# 2   HHCJ44        40  GUSTAVO TEJADA   956888283.0  15,932,284-K
# 3   FTJR69        12   RAFAEL QUISAS   950033871.0  13,369,058-1
# 4   JKBB71         8     RENE MORALES  996740759.0  17,340,561-8
#
#               AYUDANTE         RUT.1
# 0   MATIAS BUSTAMANTE   19,289,574-K
# 1       JOSE ARRIAGADA  12,641,807-8
# 2          FELIPE MORA  17,762,756-9
# 3      VICTOR CARRASCO  16,516,882-8
# 4  PEDRO DELGADO 25/08  25,821,753-5

# %%
import folium
from folium import features

mapa = folium.Map(location=[df.iloc[0][5],df.iloc[0][6]],zoom_start=11)

fg=folium.FeatureGroup()  
for n in range(len(df)): 
    fg.add_child(folium.CircleMarker(location=[df.iloc[n][5],df.iloc[n][6]],radius=3,
                                     color='#ff0000',fill = True,fill_color='#ff0000'))
    
fg.add_child(folium.Marker(location=[df.iloc[0][5],df.iloc[0][6]],
                           popup=folium.Popup(df.iloc[0][0]),
                           icon=folium.Icon(color='green',
                                            icon_color='white',icon='info-sign')))
    
mapa.add_child(fg)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##  <font color= #B30838> Data Structure and Sets </font>

# %%
# Sets:
C=[ x for x in range(1,len(df))]
N=[x for x in range(len(df))]
K=[x for x in range(len(fleet))]

# %%
# Arcs:
conextion=[(i,j,k) for i in N for j in N for k in K if i!=j]
subconextion=[(i,k) for i in N for k in K]

# %%
# Demand in each nodes.
q={i:df.iloc[i][1]for i in range(1,len(df))}

# %%
d_ijk = {(i,j,k):distance.distance((df.iloc[i][5],df.iloc[i][6]), 
                                           (df.iloc[j][5],df.iloc[j][6])).km for i in N for j in N for k in K if i!=j}

# %%
s={i:df.iloc[i][2] for i in C}

# %%
t_ijk={(i,j,k):d_ijk[(i,j,k)]/3 for i,j,k in conextion}

# %%
from datetime import datetime
datetime_object = datetime.strptime('8:00', '%I:%M')
datetime_object
# Out:
# datetime.datetime(1900, 1, 1, 8, 0)

# %%
inicial_t={i:(df.iloc[i][4].hour-datetime_object.hour)*60+ df.iloc[i][4].minute for i in C}
final_t={i:(df.iloc[i][3].hour-datetime_object.hour)*60+ df.iloc[i][3].minute for i in C}

# %%
fleet
# Out:
#    PATENTE   VOLUMEN                     CHOFER      CELULAR           RUT  \
# 0    HKRT76        25              CARLOS LOPEZ  966465979.0  13,669,063-9
# 1    JDFV82        40             ESTEBAN DURAN  966337566.0  15,372,778-3
# 2    HHCJ44        40           GUSTAVO TEJADA   956888283.0  15,932,284-K
# 3    FTJR69        12            RAFAEL QUISAS   950033871.0  13,369,058-1
# 4    JKBB71         8              RENE MORALES  996740759.0  17,340,561-8
# 5    JRLB92        12            FELIPE BAUERLE  950102220.0  13,688,110-8
# 6    WA8451        12               CARLOS VINE  983936564.0   9,603,686-8
# 7    GDPJ14        12          ALEJANDRA GARCIA  991575907.0   9,959,965-0
# 8    VG5505        12              ROCIO OSORIO  950353803.0  19,111,720-4
# 9    JGYR84        12              HECTOR PALMA  998941083.0   9,831,179-3
# 10   JCZY28        12               MARIO PEREZ  981474823.0  19,172,489-5
# 11   JCZX82        12                FELIPE CEA  978701626.0  19,182,650-7
# 12   WD8807        12              JUAN CATALAN  997765822.0   8,338,825-0
# 13   FRJD61        12                 JUAN SOTO  953972165.0   9,389,799-4
# 14   KCFR81        12             FRANCO TORRES  950100336.0  17,054,779-9
# 15   DVSF44        12               JOSE MUJICA  941569583.0   9,118,322-6
# 16   FFGR11        12        MARIA JOSE MOLINA   931200297.0  17,635,391-0
# 17   JKVX17        12          LEONARDO RAMIREZ  994434721.0  16,296,410-0
# 18   JRWH55        12                 RAUL SAES  964571336.0  19,185,625-2
# 19   WF1709        12           LUIS RECABARREN  956888289.0   5,276,077-1
# 20   CTSF69        12               JUAN EASTON  994549613.0   5,200,244-3
# 21   YJ8973         8            ROBERTO AVALOZ  999651606.0  17,248,952-4
# 22   JJTJ21        12            JONATAN ARENAS  945435986.0  18,151,210-5
# 23   GHGX98        12           MIGUEL VILLEGAS  971356811.0  25,880,108-3
# 24   BFFZ29        12              MANUEL MUÑOZ  965684945.0  15,772,880-6
# 25   CFJC10        12              NELSON BARRA  951687262.0  10,170,321-5
# 26   KBDX68        12               LUIS RIVERA  977923692.0  14,345,259-K
# 27   CHBW86        40               JORGE LORCA  973950553.0  16,567,842-7
# 28   JCZR73         8             SILVANA ARAYA  961498128.0  17,278,526-3
# 29   KJFD59        12            DIEGO ESCALONA  930979583.0  17,837,622-5
# 30   FWHS85        12          JOSE NORAMBUENA   941064880.0  13,499,221-2
# 31   HFVZ82        12         MANUEL SEPULVEDA   954175907.0  18,296,245-7
# 32   FFJK98        12           MARIA HUIRCAPAN  935112047.0  13,337,072-2
# 33   CGPD28        12              HANS VERGARA  965780263.0  16,717,164-8
# 34   JCZR87         8              MATIAS GODOY  956888420.0  18,829,471-5
# 35   JCZJ44        12            JOSE BAHAMONDE  956888274.0  17,839,741-9
# 36   JLJJ63        12               DANNY PEREZ  951687263.0  16,173,667-8
# 37   GXWT32        12     ALEXANDER CANTILLANA   956888434.0  18,849,512-5
# 38   JCZB16        12            MARCELO VARGAS  956888438.0  12,128,516-9
# 39   UX2405        12             JAIME SANCHEZ          NaN  12,273,744-6
# 40   KJDZ65        12            MIGUEL MONRROS  956888293.0  13,041,251-3
# 41   KHRH31        12             JOSE HUNCHUAL  956888265.0  12,364,246-5
# 42   KHRH38        12               JOSE OLGUIN  956888291.0  16,876,062-0
# 43   DXZZ38        40             EVANDRO PINTO  956888295.0  23,542,380-4
# 44   HLDL82        40  JORGE CANTILLANA JELDREZ  956888423.0   7,206,109-8
# 45   HCKJ35        40              MARCO OLGUIN  956888288.0   9,866,589-7
# 46   DCWW63        40           LEANDRO HURTADO  956888424.0  12,152,321-3
# 47   JCPD25        40             OSCAR PACHECO  956888447.0   6,824,200-2
# 48   KFGH93        40  JORGE CANTILLANA MEDINA   956888304.0  12,406,544-5
# 49   KHGV72        40           ALEJANDRO PEREZ  956888277.0  13,206,967-0
# 50   JKDS65       120             JUAN MARCHANT  956888417.0  10,474,980-1
# 51   FZYR69       120       RICARDO CANTILLANA   956888430.0   9,773,651-0
# 52   FRTV68       120               CESAR APAZA  956888426.0  11,611,600-6
#
#                 AYUDANTE                   RUT.1
# 0     MATIAS BUSTAMANTE             19,289,574-K
# 1         JOSE ARRIAGADA            12,641,807-8
# 2            FELIPE MORA            17,762,756-9
# 3        VICTOR CARRASCO            16,516,882-8
# 4    PEDRO DELGADO 25/08            25,821,753-5
# 5    MAXIMILIAMO BAUERLE            19,747,010-0
# 6       PAULA NAVARRETE             11,550,557-2
# 7        FRANCISCO LEON             14,735-723-2
# 8          YOSIMAR PEREZ            26,121,620-5
# 9            LUCAS TELLO            20,145,889-7
# 10        MILTON JIMENEZ            18,570,356-8
# 11         LUCIANO ROJAS            18,996,501-K
# 12           LUIS LOYOLA            12,139,278-K
# 13        SERGIO CATALAN             8,007,485-9
# 14      REINALDO ROMANTE            17,566,658-3
# 15        PATRICIA GOMEZ            13,771,583-K
# 16          SERGIO MUÑOZ            16,740,562-2
# 17       JESUS HERNANDEZ  14,289,245-9 PASAPORTE
# 18     CRISTOFER FAUNDES            18,076,985-4
# 19          LUIS MARQUEZ            17,312,291-8
# 20          JESUS OCANDO            26,257,867-4
# 21        BRAYAN AGUDELO            25,332,154-7
# 22  ALEJANDRO MALDONADO             19,183,212-4
# 23      CARLOS VALENCIA             17,003,148-2
# 24          VICTOR MUÑOZ             8,228,380-3
# 25     FELIPE VILLARROEL            19,096,437-K
# 26    CRISTIAN QUINTEROS            10,946,945-9
# 27          ALEXIS ARAYA            10,320,401-1
# 28    CRISTIAN QUINTEROS            10,946,945-9
# 29       SEBASTIAN JARA             18,242,053-0
# 30       NESTOR CARNEYRO             7,985,925-7
# 31         MARTA REINADO            12,190,210-9
# 32          JOCELYN MOYA            15,411,661-3
# 33        BARBARA AZARES            16,745,026-1
# 34     SEBASTIAN ALARCON            17,283,202-4
# 35           NECTOR SOTO            20,042,532-4
# 36            JOSE BARRA            12,683,626-0
# 37       DIEGO HERNANDEZ            18,695,095-K
# 38          LUKAS VARGAS            20,289,473-9
# 39         MATIAS CASTRO            19,844,268-2
# 40            ALDO ROSAS            18,184,721-2
# 41        GUILLERMO PINO             6,228,581-8
# 42          MATIAS PEREZ            20,203,655-4
# 43         LUIS MARTINEZ             9,603,815-1
# 44           MARCO MELLA            12,906,090-5
# 45        VICENTE OLGUIN            17,600,778-8
# 46           DANIEL TORO            18,765,024-0
# 47     SAMUEL BALLADARES            18,278,655-1
# 48           OSCAR GODOY            17,049,177-7
# 49     CRISTIAN MARISCAL            19,501,728-K
# 50        SERGIO BIZARRO            19,501,862-6
# 51        JOSEP GONZALEZ            17,723,296-3
# 52         JORGE RAMIREZ            19,004,764-4

# %%
cap={i:fleet.iloc[i][1] for i in K}

# %% [markdown]
# # Optimization

# %%
# Lower and upper bound
T=720

# %%
# Cplex Opt
from docplex.mp.model import Model

# %%
mdl=Model('CVRP-TW')

# %%
x=mdl.binary_var_dict(conextion,name='x')
t=mdl.continuous_var_dict(subconextion,ub=T,name='t')

# %%
#Objetive Function:

mdl.minimize(mdl.sum(x[i,j,k]*d_ijk[(i,j,k)] for i in N for j in N if i!=j for k in K))

# constrains
mdl.add_constraints(mdl.sum(x[0,j,k] for j in N if j!=0)<=1 for k in K)
mdl.add_constraints(mdl.sum(x[i,0,k] for i in N if i!=0)<=1 for k in K)
mdl.add_constraints(mdl.sum(x[i,j,k] for j in N if i!=j)- mdl.sum(x[j,i,k] for j in N if i!=j)==0 for i in N for k in K)    
mdl.add_constraints(mdl.sum(x[i,j,k] for k in K for j in N if i!=j)==1 for i in C)

#indicator constrains for capacity
mdl.add_constraints(mdl.sum(q[i]*mdl.sum(x[i,j,k] for j in N if j!=i) for i in C)<=cap[k] for k in K)

#indicator constrains for time Windows
mdl.add_indicator_constraints(mdl.indicator_constraint(x[i,j,k],t[i,k]+s[i]+t_ijk[(i,j,k)]==t[j,k]) for k in K for i in C for j in C if i!=j)

mdl.add_constraints(t[i,k]>=inicial_t[i] for k in K for i in C)
mdl.add_constraints(t[i,k]<=final_t[i] for k in K for i in C)

mdl.print_information()
# Out:
# Model: CVRP-TW
#  - number of variables: 44573
#    - binary=43036, integer=0, continuous=1537
#  - number of constraints: 4692
#    - linear=4692
#  - parameters: defaults

# %%
mdl.parameters.timelimit=300
mdl.parameters.mip.strategy.branch=1
mdl.parameters.mip.tolerances.mipgap=0.60
solucion = mdl.solve(log_output=True)
# Out:
# CPXPARAM_TimeLimit                               300
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201703173
# CPXPARAM_MIP_Strategy_Branch                     1
# CPXPARAM_MIP_Tolerances_MIPGap                   0.59999999999999998
# Tried aggregator 3 times.
# MIP Presolve eliminated 7693 rows and 35823 columns.
# MIP Presolve modified 7645 coefficients.
# Aggregator did 5149 substitutions.
# Reduced MIP has 6353 rows, 18104 columns, and 64116 nonzeros.
# Reduced MIP has 11991 binaries, 0 generals, 0 SOSs, and 10412 indicators.
# Presolve time = 0.63 sec. (1146.48 ticks)
# Probing fixed 1085 vars, tightened 0 bounds.
# Probing time = 0.85 sec. (266.49 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 574 rows and 1670 columns.
# Aggregator did 10 substitutions.
# Reduced MIP has 5769 rows, 16424 columns, and 58013 nonzeros.
# Reduced MIP has 10895 binaries, 0 generals, 0 SOSs, and 9327 indicators.
# Presolve time = 0.13 sec. (74.66 ticks)
# Probing time = 0.03 sec. (9.51 ticks)
# Clique table members: 21744.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.04 sec. (22.56 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0       16.8390    48                     16.8390      211
#       0     0       16.8390    64                    Cuts: 65      351
#       0     0       16.8390    66                    Cuts: 27      420
#       0     2       16.8390    32                     16.8390      420
# Elapsed time = 5.07 sec. (4572.51 ticks, tree = 0.01 MB, solutions = 0)
#     171    74      418.5553     4                     16.8390     4122
#     386   125       48.7109    43                     16.8390     7019
#     643   216      367.3968     4                     16.8390    11129
#     861   279      305.9834    15                     16.8390    14301
# *  1016   319      integral     0      425.2643       16.8390    16577   96.04%
#    1067   342    infeasible            425.2643       16.8390    18172   96.04%
#    1183   388      244.4915    16      425.2643       16.8390    22245   96.04%
#    1390   432      210.3003    25      425.2643       16.8390    25679   96.04%
#    1603   508      349.3170     6      425.2643       16.8390    30825   96.04%
#    1737   552        cutoff            425.2643       16.8390    34322   96.04%
#    2366   728       90.5487    28      425.2643       16.8390    51530   96.04%
# Elapsed time = 13.56 sec. (7681.76 ticks, tree = 14.21 MB, solutions = 1)
#    2904   883        cutoff            425.2643       16.8390    69498   96.04%
#    3479  1035       53.2393    42      425.2643       16.8390    88821   96.04%
#    3953  1181       54.4681    49      425.2643       16.8390   104177   96.04%
#    4217  1282       16.8390    40      425.2643       16.8390   117986   96.04%
#    4327    44      109.0681    20      425.2643       16.8390   119572   96.04%
#    4621   122       34.2385    45      425.2643       16.8390   122852   96.04%
#    4863   189       41.3609    39      425.2643       16.8390   125831   96.04%
#    5232   292      357.6789    19      425.2643       16.8390   132316   96.04%
#    5504   383       62.5386    47      425.2643       16.8390   138536   96.04%
#    5798   424      275.8785    20      425.2643       16.8390   142748   96.04%
# Elapsed time = 42.33 sec. (20839.34 ticks, tree = 5.86 MB, solutions = 1)
#    6148   509      275.4791    13      425.2643       16.8390   149720   96.04%
#    6430   556      197.4928    22      425.2643       16.8390   154163   96.04%
#    6921   660       94.4044    39      425.2643       16.8390   162213   96.04%
#    7198   700      212.1568    16      425.2643       16.8390   165355   96.04%
#    7704   844        cutoff            425.2643       16.8390   175075   96.04%
#    7960   912      270.8906    24      425.2643       16.8390   181302   96.04%
#    8488  1023      149.8135    27      425.2643       16.8390   190219   96.04%
#    8737  1099      150.4209    42      425.2643       16.8390   197195   96.04%
#    9385  1198      242.9226    29      425.2643       16.8390   206962   96.04%
#    9664  1309      194.4110    22      425.2643       16.8390   214422   96.04%
# Elapsed time = 65.22 sec. (30410.42 ticks, tree = 25.93 MB, solutions = 1)
#   10135  1384       83.8307    37      425.2643       16.8390   219785   96.04%
# * 10488  1447      integral     0      395.6911       16.8390   226835   95.74%
#   10558  1484       17.5716    28      395.6911       16.8390   229767   95.74%
#   11082  1597      144.2651    24      395.6911       16.8390   238988   95.74%
#   11578  1741      193.2901    17      395.6911       16.8390   250202   95.74%
#   11777  1826      308.4609    22      395.6911       16.8390   259093   95.74%
#   12341  1914       39.5104    56      395.6911       16.8390   268100   95.74%
#   12842  2033       23.5091    53      395.6911       16.9611   279687   95.71%
#   13146  2155      147.0992    21      395.6911       17.0222   289236   95.70%
#   13791  2233        cutoff            395.6911       17.0832   299649   95.68%
#   14261  2354      269.9125    22      395.6911       17.0832   310780   95.68%
# Elapsed time = 88.64 sec. (40123.92 ticks, tree = 42.03 MB, solutions = 2)
#   14619  2451       51.9589    23      395.6911       17.0832   323064   95.68%
#   15269  2603      185.2020    25      395.6911       17.5335   334548   95.57%
#   15661  2720       41.5911    37      395.6911       17.5716   345899   95.56%
#   15906  2796      117.7366    35      395.6911       17.5716   353073   95.56%
#   16641  2934      271.9374    22      395.6911       17.5716   367281   95.56%
#   17272  3034       19.1640    59      395.6911       17.5716   380817   95.56%
#   17531  3139      218.2970    16      395.6911       17.5716   393119   95.56%
#   18111  3192       62.4259    32      395.6911       17.5716   399284   95.56%
#   18709  3332      292.1669    22      395.6911       17.5716   411362   95.56%
#   18931  3448      381.7831     5      395.6911       17.5716   425082   95.56%
# Elapsed time = 114.25 sec. (49683.53 ticks, tree = 57.86 MB, solutions = 2)
#   19404  3487      153.1033    43      395.6911       17.5716   430468   95.56%
#   20103  3636       25.1963    59      395.6911       17.5716   446168   95.56%
#   20726  3756      259.8610    12      395.6911       17.5716   457653   95.56%
#   21023  3913       34.4999    36      395.6911       17.5716   473281   95.56%
#   21503  3954      102.3584    36      395.6911       17.5716   477983   95.56%
#   22211  3988       17.5716    36      395.6911       17.5716   481212   95.56%
#   22923  4135    infeasible            395.6911       17.5716   498843   95.56%
#   23262  4313      270.2978    40      395.6911       17.5716   515196   95.56%
#   23523  4447      285.0145    14      395.6911       17.5716   531813   95.56%
#   23895  4513      364.6653    10      395.6911       17.5716   537937   95.56%
# Elapsed time = 143.29 sec. (59324.73 ticks, tree = 64.77 MB, solutions = 2)
#   23917  4467      374.5972    24      395.6911       17.5716   535499   95.56%
#   24439  4601      257.9170    19      395.6911       17.5716   547365   95.56%
#   25177  4738      220.9603    46      395.6911       17.5716   564149   95.56%
#   25545  4795      225.2518    23      395.6911       17.5716   570425   95.56%
#   25720  4933    infeasible            395.6911       17.5716   589636   95.56%
#   26271  4934      331.7641    15      395.6911       17.5716   591283   95.56%
#   27011  5063       26.6033    37      395.6911       17.5716   606634   95.56%
#   27801  5248      168.4170    41      395.6911       17.5716   632023   95.56%
#   28203  5357      279.2884    14      395.6911       17.5716   640870   95.56%
# * 28219+ 5281                          388.7171       17.5716            95.48%
#   28431  5476      111.3462    40      388.7171       17.5716   653323   95.48%
# Elapsed time = 174.72 sec. (70388.81 ticks, tree = 74.02 MB, solutions = 2)
#   28778  5521    infeasible            388.7171       17.5716   658591   95.48%
#   29374  5669       59.9228    26      388.7171       17.5716   677415   95.48%
#   29919  5713      140.4128    29      388.7171       17.5716   681763   95.48%
#   30044  5778       17.7947    62      388.7171       17.5716   689119   95.48%
#   30365  5903      128.8072    45      388.7171       17.5716   702896   95.48%
#   30931  6005       20.4466    50      388.7171       17.5716   714301   95.48%
#   31531  6111       53.8916    63      388.7171       17.5716   725663   95.48%
#   31986  6180      157.7301    31      388.7171       17.5716   734230   95.48%
#   32073  6270       48.9129    56      388.7171       17.5716   741752   95.48%
#   32468  6331      343.1752    20      388.7171       17.5716   750086   95.48%
# Elapsed time = 194.92 sec. (79946.97 ticks, tree = 85.39 MB, solutions = 2)
#   33065  6396       80.6140    46      388.7171       17.5716   757178   95.48%
#   33793  6571      177.7948    29      388.7171       17.5716   778288   95.48%
#   34164  6620       35.7959    55      388.7171       17.5716   784274   95.48%
#   34362  6778       89.4066    34      388.7171       17.5716   797837   95.48%
#   35108  6802      227.8020    32      388.7171       17.5716   801748   95.48%
#   35890  7033      153.8912    30      388.7171       17.5716   824703   95.48%
#   36667  7082    infeasible            388.7171       17.5716   832119   95.48%
#   37288  7357      337.4136     6      388.7171       17.5716   862610   95.48%
#   37548  7433       50.1245    44      388.7171       17.5716   871669   95.48%
#   38002  7498      274.4607     6      388.7171       17.5716   878779   95.48%
# Elapsed time = 216.73 sec. (89569.37 ticks, tree = 109.55 MB, solutions = 3)
#   38631  7503    infeasible            388.7171       17.5716   880980   95.48%
#   39105  7739      159.8473    25      388.7171       18.0256   905253   95.36%
#   39828  7851      279.9367    28      388.7171       18.2526   916212   95.30%
#   40535  7979      339.9869    36      388.7171       18.2526   934481   95.30%
#   40754  8163    infeasible            388.7171       18.2526   958595   95.30%
#   40926  8166       73.7026    36      388.7171       18.2526   959205   95.30%
#   41488  8207       42.3479    51      388.7171       18.2526   962705   95.30%
#   41516  8174      127.0857    43      388.7171       18.2526   960361   95.30%
#   41726  8252      269.9310    19      388.7171       18.2526   969015   95.30%
#   44127  8795      161.5939    38      388.7171       18.2526  1034461   95.30%
# Elapsed time = 243.44 sec. (102723.79 ticks, tree = 117.79 MB, solutions = 3)
#   46853  9187    infeasible            388.7171       18.2526  1083052   95.30%
#   48744  9623       50.3515    43      388.7171       18.2526  1124180   95.30%
#   50499 10073       33.9302    43      388.7171       18.2526  1174255   95.30%
#   52766 10456    infeasible            388.7171       18.2526  1225609   95.30%
# * 52776+10513                          386.6224       18.2526            95.28%
#   53931 10700      107.7147    35      386.6224       18.2526  1258838   95.28%
# * 54006+10707                          384.4128       18.2526            95.25%
#   55608 11046    infeasible            384.4128       18.2546  1312901   95.25%
#
# Cover cuts applied:  68
# Implied bound cuts applied:  607
# Gomory fractional cuts applied:  12
#
# Root node processing (before b&c):
#   Real time             =    5.07 sec. (4570.89 ticks)
# Parallel b&c, 4 threads:
#   Real time             =  295.03 sec. (124000.65 ticks)
#   Sync time (average)   =   39.27 sec.
#   Wait time (average)   =    0.20 sec.
#                           ------------
# Total (root+branch&cut) =  300.09 sec. (128571.54 ticks)

# %%
mdl.get_solve_status()
# Out:
# <JobSolveStatus.FEASIBLE_SOLUTION: 1>

# %%
try:
    print(solucion.get_objective_value())
except:
    print("INFEASIBLE_SOLUTION")
# Out:
# 384.41278643859187

# %%
clusters=[]
truck=[]
for k in K:
    for i in C:
        if x[0,i,k].solution_value>0.9:
            aux=[0,i]
            while i!=0:
                j=i
                for h in N:
                    if j!=h and x[j,h,k].solution_value>0.9:
                        aux.append(h)
                        i=h
            clusters.append(aux)
            truck.append(k)
print(clusters)
print(truck)
# Out:
# [[0, 25, 21, 0], [0, 17, 18, 13, 0], [0, 12, 8, 11, 0], [0, 7, 15, 16, 0], [0, 14, 9, 0], [0, 23, 24, 0], [0, 10, 6, 0], [0, 4, 5, 0], [0, 28, 26, 22, 0], [0, 2, 3, 1, 0], [0, 27, 19, 20, 0]]
# [0, 1, 27, 43, 44, 46, 48, 49, 50, 51, 52]

# %%
# Saving the clusters
#import json
#with open('clusters.json','w') as outfile:json.dump(clusters,outfile)

# %%
# Getting the routes for clusters
import json
json_data=open('/Users/sergiocorreasantis/Desktop/route_osrm2.json').read()

data = json.loads(json_data)

# %%
capacity=[]
for i in range(len(clusters)):
    x=0
    for j in range(len(clusters[i])):
        x=x+df.iloc[clusters[i][j]][1]
    capacity.append(x)

# %%
# Obtener impresión con las direeciones a seguir.
print("Solución VRP - Sansomite")
print("*******************************************************************************")
# calculando la capacidad utilizada. 
for i in range(len(clusters)):
   
    print("Route nº "+str(i+1))
    print("Camión Patente: "+str(fleet.iloc[i][0]))
    print("Capacidad del Camión : "+str(fleet.iloc[i][1]))
    utilizacion=(capacity[i]/fleet.iloc[truck[i]][1])
    print("utilization "+str(round(utilizacion,2)*100)+'%')
    for j in range(1,len(clusters[i])-1):
           print(df.iloc[clusters[i][j]][0])
    print("-------------------------------------------------------------------------------")
# Out:
# Solución VRP - Sansomite
# *******************************************************************************
# Route nº 1
# Camión Patente: HKRT76
# Capacidad del Camión : 25
# utilization 73.0%
# Loc 36 SAX Mall Arauco Maipu
# Loc 64 SEC Mall Arauco Maipu
# -------------------------------------------------------------------------------
# Route nº 2
# Camión Patente: JDFV82
# Capacidad del Camión : 40
# utilization 81.0%
# Loc 98 SEC Mall Sur
# Loc 65 SAX Mall Sur
# Loc 65 SAX Mall Sur
# -------------------------------------------------------------------------------
# Route nº 3
# Camión Patente: HHCJ44
# Capacidad del Camión : 40
# utilization 89.0%
# Loc 82 SAX Mall Oeste 2
# Loc 82 SAX Mall Oeste 2
# Loc 82 SAX Mall Oeste 2
# -------------------------------------------------------------------------------
# Route nº 4
# Camión Patente: FTJR69
# Capacidad del Camión : 12
# utilization 83.0%
# Loc 79 SEC Mall Oeste
# Loc 65 SAX Mall Sur
# Loc 65 SAX Mall Sur
# -------------------------------------------------------------------------------
# Route nº 5
# Camión Patente: JKBB71
# Capacidad del Camión : 8
# utilization 75.0%
# Loc 22 XTR Mall Vespucio
# Loc 82 SAX Mall Oeste 2
# -------------------------------------------------------------------------------
# Route nº 6
# Camión Patente: JRLB92
# Capacidad del Camión : 12
# utilization 81.0%
# Loc 36 SAX Mall Arauco Maipu
# Loc 11 XTR Mall Arauco Maipu
# -------------------------------------------------------------------------------
# Route nº 7
# Camión Patente: WA8451
# Capacidad del Camión : 12
# utilization 74.0%
# Loc 03 XTR Mall Oeste
# Loc 03 XTR Mall Oeste
# -------------------------------------------------------------------------------
# Route nº 8
# Camión Patente: GDPJ14
# Capacidad del Camión : 12
# utilization 74.0%
# Loc 57 SAM Alto Las Condes
# Loc 57 SAM Alto Las Condes
# -------------------------------------------------------------------------------
# Route nº 9
# Camión Patente: VG5505
# Capacidad del Camión : 12
# utilization 50.0%
# Loc 78 SAX Outlet Vivo Maipu
# Loc 78 SAX Outlet Vivo Maipu
# Loc 78 SAX Outlet Vivo Maipu
# -------------------------------------------------------------------------------
# Route nº 10
# Camión Patente: JGYR84
# Capacidad del Camión : 12
# utilization 50.0%
# Loc B2 SAX Outlet Irarrazabal
# Loc B2 SAX Outlet Irarrazabal
# Loc B2 SAX Outlet Irarrazabal
# -------------------------------------------------------------------------------
# Route nº 11
# Camión Patente: JCZY28
# Capacidad del Camión : 12
# utilization 69.0%
# Loc 36 SAX Mall Arauco Maipu
# Loc 11 XTR Mall Arauco Maipu
# Loc 36 SAX Mall Arauco Maipu
# -------------------------------------------------------------------------------

# %%
mapa = folium.Map(location=[df.iloc[0][5],df.iloc[0][6]],zoom_start=10.5)

color = {0:'#99b433',1:'#00a300',2:'#ff0097',3:'#9f00a7',4:'#603cba',5:'#2d89ef',6:'#2b5797',
        7:'#00aba9',8:'#ffc40d',9:'#da532c',10:'#ee1111',11:'#b91d47',12:'#eff4ff',13:'#1d1d1d'}

fg=folium.FeatureGroup()  
for n in range(len(df)): 
    fg.add_child(folium.CircleMarker(location=[df.iloc[n][5],df.iloc[n][6]],radius=2,
                                     color='#ff0000',fill = True,fill_color='#ff0000'))
for i in range(len(clusters)):
    for j in range(len(clusters[i])-1):
        try:
            
            lista=data[str(clusters[i][j])+','+str(clusters[i][j+1])]
            for n in range(len(lista)-1):
                linea=folium.PolyLine(locations=[[lista[n][1],lista[n][0]],[lista[n+1][1],lista[n+1][0]]],weight=5,color=color[i])
                mapa.add_child(linea)
        
        except:
            print("error: "+str(i)+","+str(j))
        
fg.add_child(folium.Marker(location=[df.iloc[0][5],df.iloc[0][6]],
                           popup=folium.Popup(df.iloc[0][1]),
                           icon=folium.Icon(color='green',
                                            icon_color='white',icon='info-sign')))
mapa.add_child(fg)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
