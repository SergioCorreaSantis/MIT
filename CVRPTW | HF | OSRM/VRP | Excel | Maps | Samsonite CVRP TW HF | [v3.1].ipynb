# %% [markdown]
# ![title](MIT.png)
#
#  #  <font color='#B30838'> Vehicle Routing Problem - VRP | Cplex | V[3]. </font>
#
# <div class="alert alert-info">  </h4> **Rich Vehicle Routing problem with Capacity contratins, Time Windows and Heterogeneous Fleet.**
# </h4> </div>
#
#
# ##  <font color= #B30838> Descripción del Problema </font>
#
# **Problema de Samsonite: VRP, con capacidad, ventanas de tiempo, tiempo de viaje y tiempo de servicio.** Esta versión es solo de prueba del modelo, luego se modificará la función objetivo para minimizar el número de camiones a utilizar y flota heterogenea.
#
# - $C:$ Set of Clients $C=(1,2,3....n)$
# - $Nodes (N) = \{0\} \cup C$ Set of Node where "0" represet the DC.
# - $K:$ Set of Vehicule $K=(1,2,3,....K)$
# - $Arch= \{(i,j) \in N^2 : i \neq j\}$
# - $Conextions= \{(i,j,k) \in N^3 : i \neq j \; ; \; k  \in K \}$
# - $SubConextion= \{(i,k) \in N^2 : i \in C \; ; \; k  \in K \}$
#
#
# - $d_{ijk}:$ Distance from node i to j with truck k $(i,j,k)\in Conextions$
# - $q_i$ Customer's demand $i$ with $i\in Clientes$
# - $s_{i}:$ service time in each client $i$ with $i \in Clientes$
# - $t_{ij}:$ traveling Time from $i$ to $j$ with the vehicule $k$ $i,j \in Nodos$ & $k \in K$
# - $k_{i}$ capacity of the vehicle $k$ with $i \in K$
#
# ##  <font color= #B30838> Formulación Matemática del Problema </font>
#
#
# ####  <font color= #B30838> Variables de Decisión </font>
#
# - $x_{ijk}$ equals to 1 if we go from arch $i$ to arch $j$ with truck $k$ with $i,j \in C$ and $k \in K$ other way $0$.
# - $t_{ik}$ accumulated time in the node $i$ with the truck $k$ with $ i \in Clientes$ & $k \in K$
#
# ####  <font color= #B30838> Modelo </font>
#
# $Min \; Z= \; \displaystyle\sum_{k\in K}^{} \displaystyle\sum_{(i,j)\in A}^{}x_{ijk}c_{i}$
#
# subjet to:
#
#
# $\displaystyle\sum_{j \in N}x_{0jk} \leq 1$  $\;\; \forall \;k \in K$
#
# $\displaystyle\sum_{i \in N}x_{i0k} \leq 1$  $\;\; \forall \;k \in K$
#
# $\displaystyle\sum_{i \in N}x_{ijk}-\displaystyle\sum_{i \in N}x_{jik} =0$ $\;\; \forall \; j \in C \; \forall \; k \in K$
#
#
# $\displaystyle\sum_{j \in N}\displaystyle\sum_{k \in k}x_{ijk}=1$  $\;\; \forall i \in C$
#
# $\displaystyle\sum_{i \in N}q_{i}\displaystyle\sum_{j \in \delta^{+}(i)}x_{ijk}=k_{k}$ $\;\; \forall \;k \in K$
#
# if $x_{ijk}=1 \Longrightarrow$ $t_{ik}+s{i}+t_{ij}=t_{jk}$ $\;\; \forall \;k \in K,\;(i,j) \in A $
#
# $a_i \leq t_{ik} \leq b$   $\;\; \forall \;k \in K, \; \; i \in C$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import googlemaps
import folium
from folium import features
from geopy import distance
from datetime import datetime
from docplex.mp.model import Model

# %%
excel=pd.ExcelFile('Pedidos.xlsx')
df =pd.read_excel(excel,'Datos')

# %%
excel=pd.ExcelFile('TimeWindows.xlsx')
TimeWindows =pd.read_excel(excel,'Sheet1')

# %%
# completar el DF con la información de TimeWindows

df['Inicio']=''
df['Final']=''
df['Duracion']=''
for i in range(len(df)):
    for j in range(len(TimeWindows)):
        if df.iloc[i][0]==TimeWindows.iloc[j][0]:
            df.at[i,'Inicio']=TimeWindows.iloc[j][1]
            df.at[i,'Final']=TimeWindows.iloc[j][2]
            df.at[i,'Duracion']=TimeWindows.iloc[j][3]*60

# %%
data=[]
data.insert(0,{'Cliente': 'Camino lo Boza 120-B, Pudahuel','Demanda': 0,
               'Inicio': 0,'Final': 0,'Duracion': 0})
df=pd.concat([pd.DataFrame(data), df], ignore_index=True)
df.head()
# Out:
#                           Cliente    Demanda Duracion     Final    Inicio
# 0  Camino lo Boza 120-B, Pudahuel   0.000000        0         0         0
# 1   Loc B2 SAX Outlet Irarrazabal   2.800000       60  11:30:00  09:30:00
# 2   Loc B2 SAX Outlet Irarrazabal  15.666667       60  11:30:00  09:30:00
# 3   Loc B2 SAX Outlet Irarrazabal  41.000000       60  11:30:00  09:30:00
# 4      Loc 57 SAM Alto Las Condes   3.800000       90  11:00:00  09:00:00

# %%
df['lat']=''
df['lon']=''

# %%
gmaps_key=googlemaps.Client(key="AIzaSyCCYm4751apdVLwDkG_QhLagjP7xNzt8Ac")
df['lat']=''
df['lon']=''

for n in range(len(df)):
    geocode_resultado=gmaps_key.geocode(df.iloc[n][0]+",Santiago"+",Chile")
    try:
        lat=geocode_resultado[0]["geometry"]["location"]["lat"]
        lon=geocode_resultado[0]["geometry"]["location"]["lng"]
        df.at[n,'lat']=lat
        df.at[n,'lon']=lon
    except:
        lat=None
        lon=None
df.head()
# Out:
#                           Cliente    Demanda Duracion     Final    Inicio  \
# 0  Camino lo Boza 120-B, Pudahuel   0.000000        0         0         0
# 1   Loc B2 SAX Outlet Irarrazabal   2.800000       60  11:30:00  09:30:00
# 2   Loc B2 SAX Outlet Irarrazabal  15.666667       60  11:30:00  09:30:00
# 3   Loc B2 SAX Outlet Irarrazabal  41.000000       60  11:30:00  09:30:00
# 4      Loc 57 SAM Alto Las Condes   3.800000       90  11:00:00  09:00:00
#
#        lat      lon
# 0  -33.382  -70.768
# 1 -33.4539 -70.6016
# 2 -33.4539 -70.6016
# 3 -33.4539 -70.6016
# 4 -33.3908  -70.546

# %%
excel=pd.ExcelFile('FLOTA CAMIONES.xlsx')
fleet =pd.read_excel(excel,'Hoja1')
fleet.head()
# Out:
#   PATENTE   VOLUMEN            CHOFER      CELULAR           RUT  \
# 0   HKRT76        25     CARLOS LOPEZ  966465979.0  13,669,063-9
# 1   JDFV82        40    ESTEBAN DURAN  966337566.0  15,372,778-3
# 2   HHCJ44        40  GUSTAVO TEJADA   956888283.0  15,932,284-K
# 3   FTJR69        12   RAFAEL QUISAS   950033871.0  13,369,058-1
# 4   JKBB71         8     RENE MORALES  996740759.0  17,340,561-8
#
#               AYUDANTE         RUT.1
# 0   MATIAS BUSTAMANTE   19,289,574-K
# 1       JOSE ARRIAGADA  12,641,807-8
# 2          FELIPE MORA  17,762,756-9
# 3      VICTOR CARRASCO  16,516,882-8
# 4  PEDRO DELGADO 25/08  25,821,753-5

# %%
import folium
from folium import features

mapa = folium.Map(location=[df.iloc[0][5],df.iloc[0][6]],zoom_start=11)

fg=folium.FeatureGroup()  
for n in range(len(df)): 
    fg.add_child(folium.CircleMarker(location=[df.iloc[n][5],df.iloc[n][6]],radius=3,
                                     color='#ff0000',fill = True,fill_color='#ff0000'))
    
fg.add_child(folium.Marker(location=[df.iloc[0][5],df.iloc[0][6]],
                           popup=folium.Popup(df.iloc[0][0]),
                           icon=folium.Icon(color='green',
                                            icon_color='white',icon='info-sign')))
    
mapa.add_child(fg)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##  <font color= #B30838> Data Structure and Sets </font>

# %%
# Sets:
C=[ x for x in range(1,len(df))]
N=[x for x in range(len(df))]
K=[x for x in range(len(fleet))]

# %%
# Arcs:
conextion=[(i,j,k) for i in N for j in N for k in K if i!=j]
subconextion=[(i,k) for i in N for k in K]

# %%
# Demand in each nodes.
q={i:df.iloc[i][1]for i in range(1,len(df))}

# %%
d_ijk = {(i,j,k):distance.distance((df.iloc[i][5],df.iloc[i][6]), 
                                           (df.iloc[j][5],df.iloc[j][6])).km for i in N for j in N for k in K if i!=j}

# %%
s={i:df.iloc[i][2] for i in C}

# %%
t_ijk={(i,j,k):d_ijk[(i,j,k)]/3 for i,j,k in conextion}

# %%
from datetime import datetime
datetime_object = datetime.strptime('8:00', '%I:%M')
datetime_object
# Out:
# datetime.datetime(1900, 1, 1, 8, 0)

# %%
inicial_t={i:(df.iloc[i][4].hour-datetime_object.hour)*60+ df.iloc[i][4].minute for i in C}
final_t={i:(df.iloc[i][3].hour-datetime_object.hour)*60+ df.iloc[i][3].minute for i in C}

# %%
cap={i:fleet.iloc[i][1] for i in K}

# %% [markdown]
# # Optimization

# %%
# Lower and upper bound
T=720

# %%
# Cplex Opt
from docplex.mp.model import Model

# %%
mdl=Model('CVRP-TW')

# %%
x=mdl.binary_var_dict(conextion,name='x')
t=mdl.continuous_var_dict(subconextion,ub=T,name='t')

# %%
#Objetive Function:

mdl.minimize(mdl.sum(x[i,j,k]*d_ijk[(i,j,k)] for i in N for j in N if i!=j for k in K))

# constrains
mdl.add_constraints(mdl.sum(x[0,j,k] for j in N if j!=0)<=1 for k in K)
mdl.add_constraints(mdl.sum(x[i,0,k] for i in N if i!=0)<=1 for k in K)
mdl.add_constraints(mdl.sum(x[i,j,k] for j in N if i!=j)- mdl.sum(x[j,i,k] for j in N if i!=j)==0 for i in N for k in K)    
mdl.add_constraints(mdl.sum(x[i,j,k] for k in K for j in N if i!=j)==1 for i in C)

#indicator constrains for capacity
mdl.add_constraints(mdl.sum(q[i]*mdl.sum(x[i,j,k] for j in N if j!=i) for i in C)<=cap[k] for k in K)

#indicator constrains for time Windows
mdl.add_indicator_constraints(mdl.indicator_constraint(x[i,j,k],t[i,k]+s[i]+t_ijk[(i,j,k)]==t[j,k]) for k in K for i in C for j in C if i!=j)

mdl.add_constraints(t[i,k]>=inicial_t[i] for k in K for i in C)
mdl.add_constraints(t[i,k]<=final_t[i] for k in K for i in C)

mdl.print_information()
# Out:
# Model: CVRP-TW
#  - number of variables: 44573
#    - binary=43036, integer=0, continuous=1537
#  - number of constraints: 4692
#    - linear=4692
#  - parameters: defaults

# %%
mdl.parameters.timelimit=300
mdl.parameters.mip.strategy.branch=1
mdl.parameters.mip.tolerances.mipgap=0.60
solucion = mdl.solve(log_output=True)
# Out:
# CPXPARAM_TimeLimit                               300
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_RandomSeed                              201703173
# CPXPARAM_MIP_Strategy_Branch                     1
# CPXPARAM_MIP_Tolerances_MIPGap                   0.59999999999999998
# Tried aggregator 3 times.
# MIP Presolve eliminated 7693 rows and 35823 columns.
# MIP Presolve modified 7645 coefficients.
# Aggregator did 5149 substitutions.
# Reduced MIP has 6353 rows, 18104 columns, and 64116 nonzeros.
# Reduced MIP has 11991 binaries, 0 generals, 0 SOSs, and 10412 indicators.
# Presolve time = 0.87 sec. (1146.48 ticks)
# Probing fixed 1085 vars, tightened 0 bounds.
# Probing time = 1.16 sec. (266.49 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 574 rows and 1670 columns.
# Aggregator did 10 substitutions.
# Reduced MIP has 5769 rows, 16424 columns, and 58013 nonzeros.
# Reduced MIP has 10895 binaries, 0 generals, 0 SOSs, and 9327 indicators.
# Presolve time = 0.12 sec. (74.66 ticks)
# Probing time = 0.05 sec. (9.51 ticks)
# Clique table members: 21744.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.07 sec. (31.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0       16.8482    56                     16.8482      469
#       0     0       16.8482    66                    Cuts: 57      590
#       0     0       16.8482    60                    Cuts: 34      672
#       0     0       16.8482    78                   Cuts: 298      793
# *     0+    0                          432.1196       16.8482            96.10%
#       0     2       16.8482    38      432.1196       16.8482      793   96.10%
# Elapsed time = 6.51 sec. (4652.73 ticks, tree = 0.01 MB, solutions = 1)
#     141    59      217.6955    34      432.1196       16.8482     3613   96.10%
# *   235    93      integral     0      413.7453       16.8482     4891   95.93%
#     392   128      315.4398     7      413.7453       16.8482     7648   95.93%
#     580   193      252.1933    26      413.7453       16.8482    11261   95.93%
#     771   266      184.1520    31      413.7453       16.8482    16589   95.93%
#     910   303      280.3209    10      413.7453       16.8482    19415   95.93%
#    1009   353      223.0773    34      413.7453       16.8482    25252   95.93%
#    1126   394      126.6768    41      413.7453       16.8482    28656   95.93%
#    1257   447      370.6621     2      413.7453       16.8482    32991   95.93%
# *  1262   447      integral     0      386.7375       16.8482    32998   95.64%
#    1317   471      135.3617    39      386.7375       16.8482    37292   95.64%
#    1739   632      317.5664     3      386.7375       16.8482    54072   95.64%
# Elapsed time = 15.20 sec. (7782.46 ticks, tree = 7.63 MB, solutions = 3)
#    2249   788      160.0830    41      386.7375       16.8482    73549   95.64%
#    2795   942      245.2724    18      386.7375       16.8482    90920   95.64%
#    3133  1091      313.1897    16      386.7375       16.8482   110878   95.64%
#    3475  1205      238.3095    23      386.7375       16.8482   126258   95.64%
#    3931  1308      235.3717    33      386.7375       16.8482   141091   95.64%
#    4167  1415       61.4414    73      386.7375       16.8482   156968   95.64%
#    4255  1461       16.8482    40      386.7375       16.8482   165274   95.64%
#    4316  1049      140.3457    43      386.7375       16.8482   165782   95.64%
#    4355    52       16.8482    44      386.7375       16.8482   165280   95.64%
#    4488    88       78.8482    26      386.7375       16.8482   167519   95.64%
# Elapsed time = 39.31 sec. (18590.41 ticks, tree = 0.84 MB, solutions = 3)
#    4718   131    infeasible            386.7375       16.8482   170889   95.64%
#    4823   156      160.3910    36      386.7375       16.8482   173466   95.64%
#    5166   212       84.0937    52      386.7375       16.8482   177294   95.64%
#    5539   280      148.0282    24      386.7375       16.8482   183478   95.64%
#    5805   380      127.4318    30      386.7375       16.8482   190845   95.64%
#    6212   487      232.9253    18      386.7375       16.8482   196463   95.64%
#    6512   578      289.1318    23      386.7375       16.8482   201238   95.64%
#    6996   672      219.3110    21      386.7375       16.8482   207303   95.64%
#    7343   746       20.2358    39      386.7375       16.8482   213166   95.64%
#    7917   827      226.8731    22      386.7375       16.8482   220172   95.64%
# Elapsed time = 60.93 sec. (28152.36 ticks, tree = 15.03 MB, solutions = 3)
#    8245   919       85.1132    34      386.7375       16.8482   227840   95.64%
#    8823  1008       41.2832    42      386.7375       16.8482   235713   95.64%
#    9189  1104      253.9016    18      386.7375       16.8482   244198   95.64%
#    9767  1184      263.6374    15      386.7375       16.8482   249983   95.64%
#   10294  1310      206.1333    16      386.7375       16.8482   258225   95.64%
#   10620  1333      260.8044    31      386.7375       16.8482   261395   95.64%
#   11398  1438      193.3015    36      386.7375       16.8482   273068   95.64%
#   11783  1574    infeasible            386.7375       16.8482   288739   95.64%
#   12401  1632       31.5342    49      386.7375       16.8482   295458   95.64%
#   12955  1721    infeasible            386.7375       16.8482   307129   95.64%
# Elapsed time = 82.54 sec. (37737.15 ticks, tree = 56.82 MB, solutions = 3)
#   13114  1806      251.3020    18      386.7375       16.8482   316490   95.64%
#   13708  1899      165.6446    35      386.7375       16.8482   328338   95.64%
#   14287  1993      227.6474    26      386.7375       16.8482   340248   95.64%
#   14439  2079      141.5226    41      386.7375       16.8482   351502   95.64%
#   14973  2134       99.0525    30      386.7375       16.8482   356688   95.64%
#   15542  2255      320.5380    14      386.7375       17.0313   369731   95.60%
#   15817  2329       17.0313    45      386.7375       17.0313   375170   95.60%
#   16356  2477      215.2314    21      386.7375       17.0924   386985   95.58%
#   17031  2638      287.7347    15      386.7375       17.0924   403769   95.58%
#   17349  2685      212.1258    22      386.7375       17.1412   409003   95.57%
# Elapsed time = 105.22 sec. (47374.59 ticks, tree = 77.05 MB, solutions = 3)
#   17675  2751      142.9959    18      386.7375       17.2145   416426   95.55%
#   18392  2830      239.2596    27      386.7375       17.2145   425401   95.55%
#   18979  3017      304.4610    20      386.7375       17.2145   441508   95.55%
#   19147  3123      194.9432    28      386.7375       17.2145   456038   95.55%
#   19510  3165       17.2145    51      386.7375       17.2145   461494   95.55%
#   20131  3326       49.8491    50      386.7375       17.2145   479237   95.55%
#   20747  3430       49.8125    29      386.7375       17.2145   488860   95.55%
#   21027  3493       17.2145    47      386.7375       17.2145   495210   95.55%
#   21060  3415      163.2200    24      386.7375       17.2145   487134   95.55%
#   21257  3592      158.5525    25      386.7375       17.2145   503986   95.55%
# Elapsed time = 127.86 sec. (56950.04 ticks, tree = 99.90 MB, solutions = 3)
#   21744  3615      342.1187    25      386.7375       17.2145   508828   95.55%
#   22296  3828      139.5146    33      386.7375       17.2145   527153   95.55%
#   22410  3834       69.9996    40      386.7375       17.2145   528058   95.55%
#   22881  3947      202.7004    14      386.7375       17.2145   540981   95.55%
#   23568  4085      233.8225    16      386.7375       17.2145   554622   95.55%
#   24293  4131    infeasible            386.7375       17.2145   558289   95.55%
#   24808  4333      105.6664    25      386.7375       17.2145   578645   95.55%
#   25020  4466       65.5774    20      386.7375       17.2145   595443   95.55%
#   25384  4524    infeasible            386.7375       17.2145   600600   95.55%
#   26088  4615    infeasible            386.7375       17.2145   611073   95.55%
# Elapsed time = 153.60 sec. (66711.87 ticks, tree = 119.49 MB, solutions = 3)
#   26772  4794       52.3532    57      386.7375       17.5808   631314   95.45%
#   27266  4879       19.9106    55      386.7375       17.5808   642255   95.45%
#   27421  5001       17.5808    54      386.7375       17.5808   658040   95.45%
# * 27568+ 4991                          378.6998       17.5808            95.36%
# * 27670+ 4991                          373.8098       17.5808            95.30%
# * 27748+ 4991                          373.1960       17.5808            95.29%
#   27816  5027       75.3523    31      373.1960       17.5808   660987   95.29%
#   28284  5094      209.4696    33      373.1960       17.5808   669394   95.29%
#   28958  5221      303.6457    20      373.1960       17.5808   682408   95.29%
#   29380  5333      149.3947    41      373.1960       17.5808   696446   95.29%
#   29518  5433       17.5808    57      373.1960       17.5808   705097   95.29%
#   29948  5536    infeasible            373.1960       17.5808   718434   95.29%
#   30677  5679      218.2358    21      373.1960       17.5808   733491   95.29%
# Elapsed time = 175.54 sec. (76373.22 ticks, tree = 155.83 MB, solutions = 6)
#   31323  5800      106.0417    32      373.1960       17.5808   749089   95.29%
#   31654  5841       87.5507    38      373.1960       17.5808   752732   95.29%
#   31871  6013      372.7951     5      373.1960       17.5808   775174   95.29%
#   32332  6056       71.3036    35      373.1960       17.5808   780727   95.29%
#   32804  6176      126.0421    35      373.1960       17.5808   794787   95.29%
#   33327  6241       67.7240    35      373.1960       17.5808   802191   95.29%
#   33836  6293       17.5808    47      373.1960       17.5808   810629   95.29%
#   34161  6365       17.5808    47      373.1960       17.5808   817173   95.29%
#   34507  6569      331.5828    15      373.1960       17.5808   837673   95.29%
#   34998  6659      272.7505    32      373.1960       17.5808   849399   95.29%
# Elapsed time = 197.20 sec. (85953.81 ticks, tree = 163.69 MB, solutions = 6)
#   35598  6698       92.7830    38      373.1960       17.5808   852385   95.29%
#   36161  6881      112.5678    33      373.1960       17.5808   872881   95.29%
#   36678  6961      351.6806    13      373.1960       17.5808   883519   95.29%
#   36812  7123      174.4408    14      373.1960       17.5808   902621   95.29%
#   37370  7164      178.5365    16      373.1960       17.5808   907187   95.29%
#   38117  7255      208.8264    31      373.1960       17.5808   921243   95.29%
#   38734  7415      189.5671    28      373.1960       17.5808   934047   95.29%
#   39223  7570      152.4170    40      373.1960       17.5808   954817   95.29%
#   39356  7738      248.7856    31      373.1960       17.5808   970915   95.29%
#   41037  8091       87.3027    30      373.1960       17.5808  1019001   95.29%
# Elapsed time = 225.83 sec. (98432.98 ticks, tree = 173.91 MB, solutions = 6)
#   42816  8425      170.2098    25      373.1960       17.5808  1053506   95.29%
#   44357  8742      212.1803    24      373.1960       17.5808  1087720   95.29%
#   45535  9159       73.4549    37      373.1960       17.8650  1138859   95.21%
#   47252  9494       18.0348    51      373.1960       17.9213  1183468   95.20%
#   49223  9924      354.8843    18      373.1960       18.0348  1232301   95.17%
#   50957 10393      244.5365    21      373.1960       18.0348  1288820   95.17%
#   52054 10552      126.2804    34      373.1960       18.0348  1309494   95.17%
#   53340 10863      128.1959    32      373.1960       18.0348  1351192   95.17%
#
# Clique cuts applied:  1
# Cover cuts applied:  61
# Implied bound cuts applied:  573
# Flow cuts applied:  1
# Mixed integer rounding cuts applied:  5
# Zero-half cuts applied:  2
# Gomory fractional cuts applied:  10
#
# Root node processing (before b&c):
#   Real time             =    6.46 sec. (4650.90 ticks)
# Parallel b&c, 4 threads:
#   Real time             =  293.65 sec. (127704.10 ticks)
#   Sync time (average)   =   41.91 sec.
#   Wait time (average)   =    0.19 sec.
#                           ------------
# Total (root+branch&cut) =  300.11 sec. (132355.00 ticks)

# %%
mdl.get_solve_status()
# Out:
# <JobSolveStatus.FEASIBLE_SOLUTION: 1>

# %%
try:
    print(solucion.get_objective_value())
except:
    print("INFEASIBLE_SOLUTION")
# Out:
# 373.1959764547439

# %%
clusters=[]
truck=[]
for k in K:
    for i in C:
        if x[0,i,k].solution_value>0.9:
            aux=[0,i]
            while i!=0:
                j=i
                for h in N:
                    if j!=h and x[j,h,k].solution_value>0.9:
                        aux.append(h)
                        i=h
            clusters.append(aux)
            truck.append(k)
print(clusters)
print(truck)
# Out:
# [[0, 5, 4, 0], [0, 7, 17, 15, 0], [0, 10, 6, 0], [0, 1, 14, 9, 0], [0, 25, 19, 23, 0], [0, 13, 18, 16, 0], [0, 12, 11, 8, 0], [0, 28, 26, 22, 0], [0, 24, 21, 27, 0], [0, 3, 2, 20, 0]]
# [2, 27, 43, 44, 45, 47, 49, 50, 51, 52]

# %%
# Saving the clusters
#import json
#with open('clusters.json','w') as outfile:json.dump(clusters,outfile)

# %%
# Getting the routes for clusters
import json
json_data=open('route_osrm2.json').read()

data = json.loads(json_data)

# %%
capacity=[]
for i in range(len(clusters)):
    x=0
    for j in range(len(clusters[i])):
        x=x+df.iloc[clusters[i][j]][1]
    capacity.append(x)

# %%
# Obtener impresión con las direeciones a seguir.
print("Solución VRP - Sansomite")
print("*******************************************************************************")
# calculando la capacidad utilizada. 
for i in range(len(clusters)):
   
    print("Route nº "+str(i+1))
    print("Camión Patente: "+str(fleet.iloc[i][0]))
    print("Capacidad del Camión : "+str(fleet.iloc[i][1]))
    utilizacion=(capacity[i]/fleet.iloc[truck[i]][1])
    print("utilization "+str(round(utilizacion,2)*100)+'%')
    for j in range(1,len(clusters[i])-1):
           print(df.iloc[clusters[i][j]][0])
    print("-------------------------------------------------------------------------------")
# Out:
# Solución VRP - Sansomite
# *******************************************************************************
# Route nº 1
# Camión Patente: HKRT76
# Capacidad del Camión : 25
# utilization 74.0%
# Loc 57 SAM Alto Las Condes
# Loc 57 SAM Alto Las Condes
# -------------------------------------------------------------------------------
# Route nº 2
# Camión Patente: JDFV82
# Capacidad del Camión : 40
# utilization 82.0%
# Loc 79 SEC Mall Oeste
# Loc 98 SEC Mall Sur
# Loc 65 SAX Mall Sur
# -------------------------------------------------------------------------------
# Route nº 3
# Camión Patente: HHCJ44
# Capacidad del Camión : 40
# utilization 74.0%
# Loc 03 XTR Mall Oeste
# Loc 03 XTR Mall Oeste
# -------------------------------------------------------------------------------
# Route nº 4
# Camión Patente: FTJR69
# Capacidad del Camión : 12
# utilization 82.0%
# Loc B2 SAX Outlet Irarrazabal
# Loc 22 XTR Mall Vespucio
# Loc 82 SAX Mall Oeste 2
# -------------------------------------------------------------------------------
# Route nº 5
# Camión Patente: JKBB71
# Capacidad del Camión : 8
# utilization 96.0%
# Loc 36 SAX Mall Arauco Maipu
# Loc 11 XTR Mall Arauco Maipu
# Loc 36 SAX Mall Arauco Maipu
# -------------------------------------------------------------------------------
# Route nº 6
# Camión Patente: JRLB92
# Capacidad del Camión : 12
# utilization 82.0%
# Loc 65 SAX Mall Sur
# Loc 65 SAX Mall Sur
# Loc 65 SAX Mall Sur
# -------------------------------------------------------------------------------
# Route nº 7
# Camión Patente: WA8451
# Capacidad del Camión : 12
# utilization 89.0%
# Loc 82 SAX Mall Oeste 2
# Loc 82 SAX Mall Oeste 2
# Loc 82 SAX Mall Oeste 2
# -------------------------------------------------------------------------------
# Route nº 8
# Camión Patente: GDPJ14
# Capacidad del Camión : 12
# utilization 50.0%
# Loc 78 SAX Outlet Vivo Maipu
# Loc 78 SAX Outlet Vivo Maipu
# Loc 78 SAX Outlet Vivo Maipu
# -------------------------------------------------------------------------------
# Route nº 9
# Camión Patente: VG5505
# Capacidad del Camión : 12
# utilization 62.0%
# Loc 11 XTR Mall Arauco Maipu
# Loc 64 SEC Mall Arauco Maipu
# Loc 36 SAX Mall Arauco Maipu
# -------------------------------------------------------------------------------
# Route nº 10
# Camión Patente: JGYR84
# Capacidad del Camión : 12
# utilization 64.0%
# Loc B2 SAX Outlet Irarrazabal
# Loc B2 SAX Outlet Irarrazabal
# Loc 36 SAX Mall Arauco Maipu
# -------------------------------------------------------------------------------

# %%
mapa = folium.Map(location=[df.iloc[0][5],df.iloc[0][6]],zoom_start=10.5)

color = {0:'#99b433',1:'#00a300',2:'#ff0097',3:'#9f00a7',4:'#603cba',5:'#2d89ef',6:'#2b5797',
        7:'#00aba9',8:'#ffc40d',9:'#da532c',10:'#ee1111',11:'#b91d47',12:'#eff4ff',13:'#1d1d1d'}

fg=folium.FeatureGroup()  
for n in range(len(df)): 
    fg.add_child(folium.CircleMarker(location=[df.iloc[n][5],df.iloc[n][6]],radius=2,
                                     color='#ff0000',fill = True,fill_color='#ff0000'))
for i in range(len(clusters)):
    for j in range(len(clusters[i])-1):
        try:
            
            lista=data[str(clusters[i][j])+','+str(clusters[i][j+1])]
            for n in range(len(lista)-1):
                linea=folium.PolyLine(locations=[[lista[n][1],lista[n][0]],[lista[n+1][1],lista[n+1][0]]],weight=5,color=color[i])
                mapa.add_child(linea)
        
        except:
            print("error: "+str(i)+","+str(j))
        
fg.add_child(folium.Marker(location=[df.iloc[0][5],df.iloc[0][6]],
                           popup=folium.Popup(df.iloc[0][1]),
                           icon=folium.Icon(color='green',
                                            icon_color='white',icon='info-sign')))
mapa.add_child(fg)
mapa
# Out:
# error: 0,0
# error: 0,1
# error: 0,2
# error: 1,1
# error: 1,2
# error: 1,3
# error: 3,0
# error: 3,1
# error: 4,1
# error: 4,2
# error: 4,3
# error: 5,0
# error: 5,1
# error: 5,2
# error: 6,1
# error: 6,2
# error: 6,3
# error: 8,0
# error: 8,1
# error: 8,2
# error: 8,3
# error: 9,0
# error: 9,1
# error: 9,2
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
